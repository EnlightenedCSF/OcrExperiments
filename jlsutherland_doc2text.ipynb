# %% [markdown]
# https://github.com/jlsutherland/doc2text

# %%
import sys; sys.path.append('scripts/')

# %%
import cv2

from doc2text import *
from helpers import *
from curriedCv import *

from pylab import rcParams
# %matplotlib inline

rcParams['figure.figsize'] = 15, 9

# %%
def text_from_page(image):
    page = Page(img, page_num=1)
    page.deskew()
    return page.crop()

# %%
img = cv2.imread('data/1.jpg')
result = pipe(img, text_from_page)

show(img, result)
